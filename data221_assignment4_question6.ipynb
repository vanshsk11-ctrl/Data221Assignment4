# %%
#Import needed libraries
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input,Conv2D, MaxPooling2D, Flatten, Dense

# %%
#Split the training and testing data
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
#Normalize the pixel values from [0, 255] to [0, 1] for improved CNN training performance
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
#Reshape the flattened image data into 28x28 format with 1 channel for the CNN input
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# %%
#Build and define the CNN
fashion_model = Sequential([
    Input(shape=(28, 28, 1)),
    Conv2D(32, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(10, activation="softmax")
])

# %%
#Compile the model
fashion_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
#Train and evaluate the model, generate the accuracy score
fashion_model.fit(X_train, y_train, epochs=15)
test_loss, test_accuracy = fashion_model.evaluate(X_test, y_test)
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8491 - loss: 0.4332
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8941 - loss: 0.3030
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9048 - loss: 0.2707
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9113 - loss: 0.2501
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9166 - loss: 0.2346
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9217 - loss: 0.2196
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.9262 - loss: 0.2071
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.9302 - loss: 0.1954
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9330 - loss: 0.1865
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9365 - loss: 0.1772
# Epoch 11/15
# ...

# %%
#Display the Accuracy Score
print("Test Accuracy:", test_accuracy)
# Out:
# Test Accuracy: 0.9046000242233276

# %%
"""
CNN's are preferred over over fully connected networks for image data because they preserve the spatial structure of images where a fully connected network flatten the image which destroys the
spatial relationship and it requires a lot more parameters.

The convolution layer learns spatial features such as edges, textures, and patterns that help distinguish between different clothing categories.
"""
# Out:
# "\nCNN's are preferred over over fully connected networks for image data because they preserve the spatial structure of images where a fully connected network flatten the image which destroys the\nspatial relationship and it requires a lot more parameters.\n\nThe convolution layer learns spatial features such as edges, textures, and patterns that help distinguish between different clothing categories.\n"
